# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
## I wanted to look at ACT data first so I imported it as cal_act
#cal_act = pd.read_csv('./datasets/act_2019_ca.csv')

# %%
# Looked at what type of data was in each column, saw that ACT scores were an object
#cal_act.info()

# %%
# Needed to change * to nan type 
print(cal_act['AvgScrRead'].unique())
# Out:
# [nan '23' '21' '15' '18' '*' '29' '14' '19' '25' '27' '28' '24' '26' '17'
#  '16' '20' '22' '30' '12' '13' '32' '31']

# %%
# Changed * to nan type
cal_act['AvgScrRead'] = cal_act['AvgScrRead'].replace('*',np.nan).astype(float)
cal_act['AvgScrMath'] = cal_act['AvgScrMath'].replace('*',np.nan).astype(float)
cal_act['AvgScrEng'] = cal_act['AvgScrEng'].replace('*',np.nan).astype(float)
cal_act['AvgScrSci'] = cal_act['AvgScrSci'].replace('*',np.nan).astype(float)
cal_act['NumGE21'] = cal_act['NumGE21'].replace('*',np.nan).astype(float)
cal_act['PctGE21'] = cal_act['PctGE21'].replace('*',np.nan).astype(float)

# %%
# Checked if it worked
# cal_act.info()

# %%
# Wanted to see how many total test takers there were 
cal_act['NumTstTakr'].sum()
# Out:
# 330609.0

# %%
# Created aggrigate scores that was the average total ACT across all tests
cal_act['AvgScrath'] =  cal_act[['AvgScrRead','AvgScrEng','AvgScrMath','AvgScrSci']].mean(axis=1)

# %%
# Created Histogram of aveage ACT scores 
plt.hist(cal_act['AvgScrath']);
plt.axvline(x=(cal_act['AvgScrath'].mean()), color='Red',label = 'Mean = 22.08')
plt.legend()
plt.title('Distrbution of ACT Scores')
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.309000e+03  2309.000000  2.309000e+03  1.787000e+03    2309.000000
# mean   2.929718e+13    28.666522  2.855616e+06  1.902681e+06     828.172802
# std    1.444996e+13    14.425498  1.492574e+06  1.838954e+06   10667.048988
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964519e+06  1.254385e+05      78.000000
# 50%    3.066647e+13    30.000000  3.066548e+06  1.930288e+06     218.000000
# 75%    3.868478e+13    38.000000  3.777032e+06  3.435674e+06     497.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#          NumTstTakr   AvgScrRead    AvgScrEng   AvgScrMath    AvgScrSci  \
# count   2309.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean     143.182763    22.075299    21.204082    21.416608    21.356791
# ...

# %%
cal_no_NaN = cal_act['AvgScrath'] >= 0
cal_act[cal_no_NaN]
# Out:
# Empty DataFrame
# Columns: [CDS, CCode, CDCode, SCode, RType, SName, DName, CName, Enroll12, NumTstTakr, AvgScrRead, AvgScrEng, AvgScrMath, AvgScrSci, NumGE21, PctGE21, Year, Unnamed: 17, AvgScrath]
# Index: []

# %%
act_simply = cal_act[['DName','AvgScrath']]

# %%
cal_act[cal_no_NaN].sort_values(by='AvgScrath')
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 310   3.667710e+13   36.0  3667710.0  3630480.0     S
# 1926  3.868478e+13   38.0  3868478.0   119875.0     S
# 539   3.667710e+13   36.0  3667710.0  3630019.0     S
# 23    1.964733e+13   19.0  1964733.0   118588.0     S
# 967   1.612590e+12    1.0   161259.0   110189.0     S
# ...            ...    ...        ...        ...   ...
# 1006  1.611760e+12    1.0   161176.0   135244.0     S
# 1992  4.369534e+13   43.0  4369534.0  4337762.0     S
# 2271  1.964212e+13   19.0  1964212.0  1931880.0     S
# 1025  4.369468e+13   43.0  4369468.0  4334462.0     S
# 926   4.369468e+13   43.0  4369468.0  4334421.0     S
#
#                                               SName  \
# 310                      Citrus High (Continuation)
# 1926                        S.F. International High
# 539                  Eric Birch High (Continuation)
# 23    Alain Leroy Locke College Preparatory Academy
# ...

# %%
# Created act_simply to test merge 
act_simply = cal_act[['DName','AvgScrath','PctGE21']]
act_simply.rename(columns = {'DName':'Name'}, inplace=True)
act_simply.head()
# Out:
# /Users/tabchapman/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                     Name  AvgScrath  PctGE21
# 0       Beaumont Unified        NaN      NaN
# 1            ABC Unified        NaN      NaN
# 2  Southern Kern Unified        NaN      NaN
# 3       San Jose Unified       22.5    64.15
# 4    Los Angeles Unified       21.5    57.89

# %%
act_group = act_simplify.groupby(['DName']).mean()

# %%
pov_school = pd.read_csv('Datasets/Poverty_by_School_District.csv')

# %%
pov_school.columns = pov_school.iloc[1]

# %%
#pov_school.drop(labels = 0, axis = 0, inplace=True)
#pov_school.drop(labels = 1, axis = 0, inplace=True)

# %%
cal_school = pov_school[pov_school['State Postal Code'] == 'CA']
cal_school.head()
cal_school.loc[(cal_school['State']=='MD')
# Out:
# 1   State Postal Code State FIPS Code District ID  \
# 645                CA              06       01620
# 646                CA              06       01650
# 647                CA              06       01680
# 648                CA              06       00001
# 649                CA              06       01710
#
# 1                                        Name Estimated Total Population  \
# 645               ABC Unified School District                    108,331
# 646       Acalanes Union High School District                    118,736
# 647       Ackerman Elementary School District                      2,926
# 648  Acton-Agua Dulce Unified School District                     12,882
# 649       Adelanto Elementary School District                     60,637
#
# 1   Estimated Population 5-17  \
# 645                    17,163
# 646                     5,953
# 647                       277
# 648                     1,879
# 649                     7,067
#
# ...

# %%
'ABC Unified School District'[:-16]
# Out:
# 'ABC Unified'

# %%
cal_school['DisName'] = cal_school['Name'].str.slice(stop=-16)
# Out:
# <ipython-input-186-4f4e76c285ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cal_school['DisName'] = cal_school['Name'].str.slice(stop=-16)

# %%
cal_school
# Out:
# 1    State Postal Code State FIPS Code District ID  \
# 645                 CA              06       01620
# 646                 CA              06       01650
# 647                 CA              06       01680
# 648                 CA              06       00001
# 649                 CA              06       01710
# ...                ...             ...         ...
# 1584                CA              06       00160
# 1585                CA              06       43380
# 1586                CA              06       43410
# 1587                CA              06       43470
# 1588                CA              06       43560
#
# 1                                               Name  \
# 645                      ABC Unified School District
# 646              Acalanes Union High School District
# 647              Ackerman Elementary School District
# 648         Acton-Agua Dulce Unified School District
# 649              Adelanto Elementary School District
# ...

# %%
cal_school = pov_school[pov_school['State Postal Code'] == 'CA']
cal_school.head()
# Out:
# 1   State Postal Code State FIPS Code District ID  \
# 645                CA              06       01620
# 646                CA              06       01650
# 647                CA              06       01680
# 648                CA              06       00001
# 649                CA              06       01710
#
# 1                                        Name Estimated Total Population  \
# 645               ABC Unified School District                    108,331
# 646       Acalanes Union High School District                    118,736
# 647       Ackerman Elementary School District                      2,926
# 648  Acton-Agua Dulce Unified School District                     12,882
# 649       Adelanto Elementary School District                     60,637
#
# 1   Estimated Population 5-17  \
# 645                    17,163
# 646                     5,953
# 647                       277
# 648                     1,879
# 649                     7,067
#
# ...

# %%
#Renamed column because it was anoying to keep typing 
cal_school.rename(columns={'Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder':'pov_child'}, 
                  inplace=True)
# Out:
# /Users/tabchapman/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#cal_school['pov_child'] = cal_school['pov_child'].str.replace(',','').astype(int)

# %%
#cal_school['Estimated Population 5-17'] = cal_school['Estimated Population 5-17'].str.replace(',','').astype(int)

# %%
cal_school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 944 entries, 645 to 1588
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   State Postal Code           944 non-null    object
#  1   State FIPS Code             944 non-null    object
#  2   District ID                 944 non-null    object
#  3   Name                        944 non-null    object
#  4   Estimated Total Population  944 non-null    object
#  5   Estimated Population 5-17   944 non-null    int64
#  6   pov_child                   944 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 59.0+ KB

# %%
cal_school['Percent_Pov'] = cal_school['pov_child'] / cal_school['Estimated Population 5-17']
# Out:
# <ipython-input-205-53d9d3d5ea4d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cal_school['Percent_Pov'] = cal_school['pov_child'] / cal_school['Estimated Population 5-17']

# %%
cal_school.loc[(cal_school['Percent_Pov']>0.25)]
# Out:
# 1    State Postal Code State FIPS Code District ID  \
# 649                 CA              06       01710
# 655                 CA              06       01980
# 656                 CA              06       02010
# 657                 CA              06       02070
# 660                 CA              06       02220
# ...                ...             ...         ...
# 1558                CA              06       42210
# 1573                CA              06       42810
# 1579                CA              06       01418
# 1582                CA              06       43170
# 1585                CA              06       43380
#
# 1                                       Name Estimated Total Population  \
# 649      Adelanto Elementary School District                     60,637
# 655   Allensworth Elementary School District                        502
# 656          Alpaugh Unified School District                      1,416
# ...

# %%
#Data for presentation 
cal_school.describe()
# Out:
# 1      Estimated Population 5-17      pov_child  Percent_Pov
# count                 944.000000     944.000000   944.000000
# mean                 6897.166314    1026.617585     0.157785
# std                 24880.481181    5009.936668     0.093896
# min                     5.000000       0.000000     0.000000
# 25%                   327.250000      44.750000     0.085940
# 50%                  2042.500000     228.000000     0.141952
# 75%                  6611.500000     819.750000     0.212222
# max                688725.000000  142752.000000     0.612903

# %%
#cal_school.sort_values(by='Percent_Pov')

# %%
cal_school['Percent_Pov']
# Out:
# 645     0.122706
# 646     0.025701
# 647     0.122744
# 648     0.102714
# 649     0.261073
#           ...
# 1584    0.091667
# 1585    0.285433
# 1586    0.216707
# 1587    0.174115
# 1588    0.116760
# Name: Percent_Pov, Length: 944, dtype: float64

# %%
pov_simple = cal_school[['DisName','Estimated Population 5-17','Percent_Pov']]

# %%
#
act_group.head()
plt.hist(act_group['AvgScrath']);

# %%
act_merged = act_simplify.merge(pov_simple,how='left', left_on = 'DName', right_on = 'DisName')

# %%
# First Scatter plot looking at 
plt.scatter(x=act_merged['Percent_Pov'],y=act_merged['AvgScrath']);
plt.title('Average ACT Scores Vs. Percent of Children in Poverty by School District')
plt.xlabel('Percent of Children in Poverty')
plt.ylabel('Average ACT Scores')
# Out:
# Text(0, 0.5, 'Average ACT Scores')

# %%
# Got corrilation numbers for act_merge
# act_merged.corr()

# %%
#graph for benchmark score plus pov for easier comparison with sat data
act_merged = cal_act.merge(pov_simple,how='left', left_on = 'DName', right_on = 'DisName')
plt.scatter(x=act_merged['Percent_Pov'],y=act_merged['PctGE21']);
plt.title('Average Scores over 21 Vs. Percent of Children in Poverty by School District')
plt.xlabel('Percent of Children in Poverty')
plt.ylabel('Average Scores over 21')
# Out:
# Text(0, 0.5, 'Average Scores over 21')

# %%
-0.609116

# Sat
cal_sat = pd.read_csv('./datasets/sat_2019_ca.csv')
cal_sat.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
#cal_sat.info()

# %%
cal_sat['PctBothBenchmark11'] = cal_sat['PctBothBenchmark11'].replace('*',np.nan).astype(float)
cal_sat['PctBothBenchmark12'] = cal_sat['PctBothBenchmark12'].replace('*',np.nan).astype(float)
cal_sat['TotalPctBenchmark'] = cal_sat[['PctBothBenchmark12','PctBothBenchmark11']].mean(axis=1)

# %%
cal_sat.describe()
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.579000e+03  2579.000000  2.579000e+03  2.579000e+03    2579.000000
# mean   2.915139e+13    28.519581  2.915138e+06  1.544913e+06     748.155487
# std    1.428328e+13    14.258173  1.428327e+06  1.812049e+06   10095.758681
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964725e+06  1.025080e+05      63.000000
# 50%    3.066597e+13    30.000000  3.066597e+06  1.377860e+05     171.000000
# 75%    3.777103e+13    37.000000  3.777103e+06  3.037422e+06     462.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#         NumTSTTakr12       Enroll11   NumTSTTakr11  TotNumBothBenchmark12  \
# count    2579.000000    2579.000000    2579.000000            1722.000000
# mean      264.274137     730.865452     320.473052             178.732288
# ...

# %%
cal_sat['NumTSTTakr11'].sum() + cal_sat['NumTSTTakr12'].sum()
# Out:
# 1508063.0

# %%
cal_act['NumTstTakr'].sum()
# Out:
# 330609.0

# %%
#I realised that the sat data doesnt have any raw score data so I had to use the percentage of students 
#who acheived benchmark guideline s
cal_sat['TotalPctBenchmark'] = cal_sat['TotalPctBenchmark'].replace('*',np.nan).astype(float)
plt.hist(cal_sat['TotalPctBenchmark']);
plt.axvline(x=(cal_sat['TotalPctBenchmark'].mean()), color='Red',label = 'Mean = 46.46')
plt.legend()
plt.xlabel('Percent of Students who Reached Benchmark')
plt.title('Distrbution of Students who Reached Benchmark ')
# Out:
# Text(0.5, 1.0, 'Distrbution of Students who Reached Benchmark ')

# %%
sat_merged = cal_sat.merge(pov_simple,how='left', left_on = 'DName', right_on = 'DisName')

# %%
# Getting corrilation rates for ACT
act_merged.corr()
# Out:
#                                 CDS     CCode    CDCode     SCode  Enroll12  \
# CDS                        1.000000  0.999931  0.935376  0.492962 -0.041086
# CCode                      0.999931  1.000000  0.933102  0.490608 -0.039504
# CDCode                     0.935376  0.933102  1.000000  0.539810 -0.073998
# SCode                      0.492962  0.490608  0.539810  1.000000 -0.041479
# Enroll12                  -0.041086 -0.039504 -0.073998 -0.041479  1.000000
# NumTstTakr                -0.042876 -0.041339 -0.074652 -0.041852  0.997859
# AvgScrRead                 0.114967  0.115212  0.096107  0.200442  0.006132
# AvgScrEng                  0.096789  0.096962  0.084179  0.186660  0.011153
# AvgScrMath                 0.096027  0.096184  0.080746  0.201310  0.013106
# AvgScrSci                  0.118037  0.118185  0.102150  0.215939  0.011677
# NumGE21                   -0.052303 -0.050160 -0.091369 -0.067171  0.994156
# ...

# %%
# Scotter plot for merged pov rate and statistics 
plt.scatter(x=sat_merged['Percent_Pov'],y=sat_merged['TotalPctBenchmark']);
plt.title('Students Over SAT Benchmark Vs. Children in Poverty by School District')
plt.xlabel('Percent of Children in Poverty')
plt.ylabel('Percent of Students Over SAT Benchmark')
# Out:
# Text(0, 0.5, 'Percent of Students Over SAT Benchmark')

# %%
sat_merged.corr()
# Out:
#                                 CDS     CCode    CDCode     SCode  Enroll12  \
# CDS                        1.000000  0.999932  1.000000  0.374236 -0.038617
# CCode                      0.999932  1.000000  0.999932  0.372386 -0.037101
# CDCode                     1.000000  0.999932  1.000000  0.374236 -0.038617
# SCode                      0.374236  0.372386  0.374236  1.000000 -0.039576
# Enroll12                  -0.038617 -0.037101 -0.038617 -0.039576  1.000000
# NumTSTTakr12              -0.040333 -0.038866 -0.040333 -0.038792  0.997740
# Enroll11                  -0.038853 -0.037344 -0.038853 -0.039545  0.999951
# NumTSTTakr11              -0.041065 -0.039621 -0.041065 -0.038593  0.992319
# TotNumBothBenchmark12     -0.045042 -0.043140 -0.045042 -0.049279  0.998448
# PctBothBenchmark12         0.134409  0.134666  0.134409  0.104812  0.011028
# TotNumBothBenchmark11     -0.044577 -0.042658 -0.044577 -0.050148  0.997702
# ...

# %%
cal_no_na = cal_sat[cal_sat.TotalPctBenchmark.notnull()]
cal_no_na.sort_values(by='TotalPctBenchmark')
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 309   1.964733e+13   19.0  1964733.0   102764.0     S
# 985   4.369427e+13   43.0  4369427.0  4330312.0     S
# 1641  1.964436e+13   19.0  1964436.0  1931617.0     S
# 727   1.964733e+13   19.0  1964733.0  1931989.0     S
# 2215  3.710371e+13   37.0  3710371.0        0.0     D
# ...            ...    ...        ...        ...   ...
# 1100  4.369468e+13   43.0  4369468.0  4334421.0     S
# 364   4.369468e+13   43.0  4369468.0  4334462.0     S
# 144   1.611760e+12    1.0   161176.0   135244.0     S
# 272   2.966357e+13   29.0  2966357.0   112367.0     S
# 1747  1.964212e+13   19.0  1964212.0  1931880.0     S
#
#                                 SName                                 DName  \
# 309   Richard A. Alonzo Community Day                   Los Angeles Unified
# 985                      Phoenix High                  East Side Union High
# 1641   Fairvalley High (Continuation)                 Covina-Valley Unified
# ...

# %%
# Getting stats for Los Angeles Unified
#cal_sat[(cal_sat['DName']=='Los Angeles Unified')].describe()

# %%
#cal_act[(cal_act['DName']=='Los Angeles Unified')].describe()
